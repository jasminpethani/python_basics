# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
import numpy as np
np
# Out:
# <module 'numpy' from '/Users/jasminp/Documents/py_app/demouv/.venv/lib/python3.14/site-packages/numpy/__init__.py'>

# %%
from math import sqrt 
from math import * 
print(pi)
# Out:
# 3.141592653589793

# %%
from package.maths import addition
addition(10,1)
# Out:
# 11
