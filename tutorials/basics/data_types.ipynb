# %%
a=10
type(a)
# Out:
# int

# %%
s="hello"

s
# Out:
# 'hello'

# %%
is_var=False
is_nil=bool() 

a=10 
b=10

print(a==b)

print(is_var)
print(is_nil)
# Out:
# True
# False
# False

# %%
result = "hello" + str(5)
print(result)
# Out:
# hello5

# %%
## Common errors 

r="hello" + 5
r
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 ## Common errors
#       2
# ----> 3 r="hello" + 5
#       4 r
#
# TypeError: can only concatenate str (not "int") to str
