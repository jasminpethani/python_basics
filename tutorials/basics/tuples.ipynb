# %%
## PACKED and UNPACKED tuples
packed_tuples = 1, "hello", 3.45

# unpacking tuples
a,b,c = packed_tuples

print(a)
print(b) 
print(c)
# Out:
# 1
# hello
# 3.45

# %%
## unpacking with *
numbers=(1,2,3,4,5,6)

first, *middle, last = numbers

print(first)
print(last)
print(middle)
# Out:
# 1
# 6
# [2, 3, 4, 5]
