# %%
## Math operators
a=20
b=10
c=10
print(a+b)
print(a-b)
print(a*b) 
print(a/b)



print(a**b)
print(a%b) # module 
print(a//b) # floor value

# %%
### Comparision Operators 
print(a==b)
print(a!=b)
print(a<b)
print(a>b)

# %%
## AND , OR , NOT
x=True
y=False
result = x and y 
result2 = x or y 
result3 = not result2

print(result)
print(result2)
print(result3)
# Out:
# False
# True
# False
